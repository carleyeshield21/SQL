# %%
import pandas
import numpy

# %%
inpatient_pat = pandas.read_csv('Inpatient_Pat.csv')
inpatient_pat
# Out:
#                                        DRG Definition  Total Discharges  \
# 0            039 - EXTRACRANIAL PROCEDURES W/O CC/MCC             37861
# 1   057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...             37927
# 2   064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFA...             68163
# 3   065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFA...            110983
# 4   066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFA...             62346
# ..                                                ...               ...
# 95                                    885 - PSYCHOSES             96597
# 96  897 - ALCOHOL/DRUG ABUSE OR DEPENDENCE W/O REH...             39977
# 97     917 - POISONING & TOXIC EFFECTS OF DRUGS W MCC             25261
# 98   918 - POISONING & TOXIC EFFECTS OF DRUGS W/O MCC             37372
# 99                     948 - SIGNS & SYMPTOMS W/O MCC             57490
#
#     Average Covered Charges  Average Total Payments  Average Medicare Payments
# ...

# %%
Inpatient_provdr = pandas.read_csv('Inpatient_provdr.csv')
Inpatient_provdr
# Out:
#                                   DRG Definition  Provider Id  \
# 0       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10005
# 2       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10006
# 3       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10011
# 4       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10016
# ...                                          ...          ...
# 163060            948 - SIGNS & SYMPTOMS W/O MCC       670041
# 163061            948 - SIGNS & SYMPTOMS W/O MCC       670055
# 163062            948 - SIGNS & SYMPTOMS W/O MCC       670056
# 163063            948 - SIGNS & SYMPTOMS W/O MCC       670060
# 163064            948 - SIGNS & SYMPTOMS W/O MCC       670068
#
#                                           Provider Name  \
# 0                      SOUTHEAST ALABAMA MEDICAL CENTER
# 1                         MARSHALL MEDICAL CENTER SOUTH
# ...

# %%
Outpatient_Pat = pandas.read_csv('Outpatient_Pat.csv')
Outpatient_Pat
# Out:
#                                                   APC  Outpatient Services  \
# 0            0012 - Level I Debridement & Destruction               275987
# 1           0013 - Level II Debridement & Destruction               434706
# 2          0015 - Level III Debridement & Destruction               509576
# 3                     0019 - Level I Excision/ Biopsy                27860
# 4                    0020 - Level II Excision/ Biopsy                40642
# 5             0073 - Level III Endoscopy Upper Airway                 9094
# 6              0074 - Level IV Endoscopy Upper Airway                17231
# 7                0078 - Level III Pulmonary Treatment               229101
# 8     0096 - Level II Noninvasive Physiologic Studies               218179
# 9                    0203 - Level IV Nerve Injections                 6748
# 10                    0204 - Level I Nerve Injections               278325
# ...

# %%
Outpatient_provdr = pandas.read_csv('Outpatient_provdr.csv')
Outpatient_provdr
# Out:
#                                             APC  Provider Id  \
# 0      0012 - Level I Debridement & Destruction        10029
# 1      0012 - Level I Debridement & Destruction        20024
# 2      0012 - Level I Debridement & Destruction        30064
# 3      0012 - Level I Debridement & Destruction        30088
# 4      0012 - Level I Debridement & Destruction        30111
# ...                                         ...          ...
# 43367    0698 - Level II Eye Tests & Treatments       520098
# 43368    0698 - Level II Eye Tests & Treatments       520100
# 43369    0698 - Level II Eye Tests & Treatments       520116
# 43370    0698 - Level II Eye Tests & Treatments       520177
# 43371    0698 - Level II Eye Tests & Treatments       670034
#
#                                            Provider Name  \
# 0                    EAST ALABAMA MEDICAL CENTER AND SNF
# 1                     CENTRAL PENINSULA GENERAL HOSPITAL
# 2       UNIVERSITY OF ARIZONA MEDICAL CTR-UNIVERSIT, THE
# ...

# %%
Patient_history_samp = pandas.read_csv('Patient_history_samp.csv')
Patient_history_samp
# Out:
#                id    age gender       income
# 0       306535165  65-74      F  24000-31999
# 1       742231134  65-74      F       48000+
# 2       928807201  75-84      M  24000-31999
# 3        83686538    <65      F  32000-47999
# 4       755607449  65-74      F       48000+
# ...           ...    ...    ...          ...
# 499995  164912939  75-84      F       48000+
# 499996  879506052  65-74      F  32000-47999
# 499997   87045563  75-84      M  32000-47999
# 499998  791132159    <65      M  32000-47999
# 499999  385254439  65-74      F  32000-47999
#
# [500000 rows x 4 columns]

# %%
Review_patient_history_samp = pandas.read_csv('Review_patient_history_samp.csv')
Review_patient_history_samp
# Out:
#              id    age gender       income
# 0     381693273  65-74      F  24000-31999
# 1     444060924  65-74      M  24000-31999
# 2       3641691  65-74      F  24000-31999
# 3     672653795  65-74      M       48000+
# 4     144916176    <65      F       48000+
# ...         ...    ...    ...          ...
# 4995   28831157    <65      M  24000-31999
# 4996  612539786    <65      F  24000-31999
# 4997  978751518  75-84      F       <16000
# 4998  105489783  75-84      M  24000-31999
# 4999  650750373    85+      F       <16000
#
# [5000 rows x 4 columns]

# %%
Rreview_transaction_coo = pandas.read_csv('Rreview_transaction_coo.csv')
Rreview_transaction_coo
# Out:
#               id  global_proc_id  count
# 0          65822             109      1
# 1          65822             125      1
# 2         119695              70      1
# 3         119695             124      1
# 4         119695             125      1
# ...          ...             ...    ...
# 15036  999454987             112      1
# 15037  999460247              69      1
# 15038  999460247              92      1
# 15039  999460247             124      1
# 15040  999921648              60      1
#
# [15041 rows x 3 columns]

# %%
Transaction_coo = pandas.read_csv('Transaction_coo.csv')
Transaction_coo
# Out:
#                 id  global_proc_id  count
# 0           159125               1      1
# 1           191852               1      1
# 2           321083               1      1
# 3           383037               1      1
# 4           467729               1      1
# ...            ...             ...    ...
# 1514804  997500356             130      1
# 1514805  997544830             130      1
# 1514806  998247161             130      1
# 1514807  998347246             130      1
# 1514808  998488395             130      1
#
# [1514809 rows x 3 columns]
